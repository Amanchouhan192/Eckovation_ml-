# %%
#FOR ZOMATO BEST AND TOP 5 RESTAURANTS (CITY WISE)
#NOTE: Make sure to change the file location according to your directory where file1.json, file2.json... are saved


import json
def zomato_citywise(x):
    a = open("C:\\Users\\Aman\\Desktop\\Eckovation_ml-\\ZomatoDataForAnalyse\\file1.json",'r',encoding='utf-8')
    zomato = json.load(a)
    a.close()

    d = {}


    for i in zomato:
        try:
            for j in range(len(i['restaurants'])):
                try:
                    
                    city = i['restaurants'][j]['restaurant']['location']['city']
                    name = i['restaurants'][j]['restaurant']['name']
                    votes = i['restaurants'][j]['restaurant']['user_rating']['votes']
                    aggre = i['restaurants'][j]['restaurant']['user_rating']['aggregate_rating']
                    rating = int(votes)*float(aggre)
                    if city not in d:
                        d[city] = {}
                    
                    d[city][rating] = name

                except:
                    continue
        except:
            continue
    
    for i in list(d):
        top = []
        keys = list(d[i].keys())
        keys = sorted(keys,reverse=True)
        print('-----------------------------------------\nFor',i,':\n','\nTotal Restaurants: ',len(keys),'\nBest Restaurant:',d[i][keys[0]])

        try:
            for j in range(5):
                top.append(d[i][keys[j]])
            print('\nTop 5 Restaurants in order of their ranks:\n',top)
        except:
            print('\nTop',len(top),'Restaurants order of their ranks:\n',top)
            continue


    return '\nDone!'

while True:
    x =input('\nEnter Filename\n->')
    zomato_citywise(x)
z = input()
# Out:
# Enter Filename
# ->file1.json
# -----------------------------------------
# For New Delhi :
#
# Total Restaurants:  15
# Best Restaurant: Hauz Khas Social
#
# Top 5 Restaurants in order of their ranks:
#  ['Hauz Khas Social', 'Saravana Bhavan', 'My Bar Headquarters', 'Farzi Cafe', 'Odeon Social']
# -----------------------------------------
# For Gurgaon :
#
# Total Restaurants:  5
# Best Restaurant: Farzi Cafe
#
# Top 5 Restaurants in order of their ranks:
#  ['Farzi Cafe', 'Manhattan Brewery & Bar Exchange', 'Molecule Air Bar', 'The Wine Company', 'Indian Grill Room']
# -----------------------------------------
# For Kolkata :
#
# Total Restaurants:  20
# Best Restaurant: Peter Cat
#
# Top 5 Restaurants in order of their ranks:
#  ['Peter Cat', 'Barbeque Nation', 'BarBQ', 'Mocambo', "Santa's Fantasea"]
# -----------------------------------------
# For Mumbai :
#
# Total Restaurants:  20
# Best Restaurant: Joey's Pizza
#
# Top 5 Restaurants in order of their ranks:
#  ["Joey's Pizza", 'Mirchi And Mime', 'SpiceKlub', "Joey's Pizza", 'The Fusion Kitchen']
# -----------------------------------------
# For Bangalore :
#
# Total Restaurants:  20
# Best Restaurant: Toit
#
# Top 5 Restaurants in order of their ranks:
#  ['Toit', 'Truffles', "AB's - Absolute Barbecues", 'Big Brewsky', 'The Black Pearl']
# -----------------------------------------
# For Pune :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Le Plaisir', 'Effingut Brewerkz', "Chili's", "Agent Jack's Bar"]
# -----------------------------------------
# For Hyderabad :
#
# Total Restaurants:  18
# Best Restaurant: AB's - Absolute Barbecues
#
# Top 5 Restaurants in order of their ranks:
#  ["AB's - Absolute Barbecues", 'Exotica', "Chili's", 'Olive Bistro', "Chili's"]
# -----------------------------------------
# For Secunderabad :
#
# Total Restaurants:  2
# Best Restaurant: Coffee Cup
#
# Top 2 Restaurants order of their ranks:
#  ['Coffee Cup', 'Saffron Mantra']
# -----------------------------------------
# For Chennai :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Pind', 'Bombay Brasserie', 'That Madras Place', 'Kaidi Kitchen']
# -----------------------------------------
# For Lucknow :
#
# Total Restaurants:  20
# Best Restaurant: Grandson of Tunday Kababi
#
# Top 5 Restaurants in order of their ranks:
#  ['Grandson of Tunday Kababi', 'Barbeque Nation', 'Vintage Machine', 'Dastarkhwan', 'Royal Sky']
# -----------------------------------------
# For Kochi :
#
# Total Restaurants:  20
# Best Restaurant: Paragon
#
# Top 5 Restaurants in order of their ranks:
#  ['Paragon', 'Dhe Puttu', 'Cocoa Tree', 'Kashi Art Cafe', "Bloomsbury's Boutique Cafe and Artisan Bakery"]
# -----------------------------------------
# For Jaipur :
#
# Total Restaurants:  20
# Best Restaurant: Tapri Central
#
# Top 5 Restaurants in order of their ranks:
#  ['Tapri Central', 'Chokhi Dhani', 'Replay', 'On The House', 'The Forresta Kitchen & Bar']
# -----------------------------------------
# For Ahmedabad :
#
# Total Restaurants:  20
# Best Restaurant: 650 - The Global Kitchen
#
# Top 5 Restaurants in order of their ranks:
#  ['650 - The Global Kitchen', "Nini's Kitchen", 'Patang - The Revolving Restaurant', 'Yanki Sizzlers', 'Mocha']
# -----------------------------------------
# For Chandigarh :
#
# Total Restaurants:  18
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', "Chili's", 'Pirates of Grill', 'Pal Dhaba', 'Virgin Courtyard']
# -----------------------------------------
# For Mohali :
#
# Total Restaurants:  1
# Best Restaurant: The Shooters Cafe
#
# Top 1 Restaurants order of their ranks:
#  ['The Shooters Cafe']
# -----------------------------------------
# For Panchkula :
#
# Total Restaurants:  1
# Best Restaurant: Hops n Grains
#
# Top 1 Restaurants order of their ranks:
#  ['Hops n Grains']
# -----------------------------------------
# For Goa :
#
# Total Restaurants:  20
# Best Restaurant: Britto's Bar & Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ["Britto's Bar & Restaurant", 'Curlies', "Martin's Corner", 'Infantaria', 'Souza Lobo']
# -----------------------------------------
# For Indore :
#
# Total Restaurants:  20
# Best Restaurant: Nafees Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ['Nafees Restaurant', 'Cafe Terazza', 'Mangosteen Cafe', '10 Downing Street', 'Vidorra']
# -----------------------------------------
# For Nashik :
#
# Total Restaurants:  20
# Best Restaurant: Sadhana Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ['Sadhana Restaurant', 'Barbeque Ville', 'Enter The Dragon', 'Al Arabian Express', 'RiverDine Restaurant & Bar']
# -----------------------------------------
# For Ludhiana :
#
# Total Restaurants:  20
# Best Restaurant: The Yellow Chilli
#
# Top 5 Restaurants in order of their ranks:
#  ['The Yellow Chilli', 'Hot Breads', 'Bistro 226', 'Aman Chicken', 'Nik Bakers']
# -----------------------------------------
# For Guwahati :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Mocha', 'Chung Fa', 'Terra Mayaa Restaurant and Lounge', 'Confucius']
# -----------------------------------------
# For Amritsar :
#
# Total Restaurants:  20
# Best Restaurant: Bharawan Da Dhaba
#
# Top 5 Restaurants in order of their ranks:
#  ['Bharawan Da Dhaba', 'Makhan Fish and Chicken Corner', 'Brothers Dhaba', 'The Kulcha Land', 'Beera Chicken Corner']
# -----------------------------------------
# For Kanpur :
#
# Total Restaurants:  19
# Best Restaurant: Aromas
#
# Top 5 Restaurants in order of their ranks:
#  ['Aromas', 'Dhuaan', 'Little Chef', 'Verandah', 'UrbanCrave']
# -----------------------------------------
# For Allahabad :
#
# Total Restaurants:  20
# Best Restaurant: Tandoor Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ['Tandoor Restaurant', 'Sagar Ratna', 'Eat On', 'Hot Stuff', 'The Tamarind Tree']
# -----------------------------------------
# For Aurangabad :
#
# Total Restaurants:  20
# Best Restaurant: Kream N Krunch
#
# Top 5 Restaurants in order of their ranks:
#  ['Kream N Krunch', 'Bhoj Restaurant', 'Madhuban Restaurant - Welcome Hotel Rama International', "d' Curry House", 'Indiana Veg Restaurant']
# -----------------------------------------
# For Bhopal :
#
# Total Restaurants:  20
# Best Restaurant: Sagar Gaire Fast Food
#
# Top 5 Restaurants in order of their ranks:
#  ['Sagar Gaire Fast Food', 'Manohar Dairy And Restaurant', '10 Downing Street', 'Manohar Dairy And Restaurant', 'Bake N Shake']
# -----------------------------------------
# For Ranchi :
#
# Total Restaurants:  20
# Best Restaurant: Kaveri Restaurant And Caterers
#
# Top 5 Restaurants in order of their ranks:
#  ['Kaveri Restaurant And Caterers', 'Yellow Sapphire', 'Moti Mahal Delux Tandoori Trail', 'KFC', 'Yo China Restaurant']
# -----------------------------------------
# For Vizag :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Flying Spaghetti Monster', 'Pizza Hut', 'Sri Sairam Parlour', 'Pizza Hut']
# -----------------------------------------
# For Bhubaneshwar :
#
# Total Restaurants:  20
# Best Restaurant: Adda
#
# Top 5 Restaurants in order of their ranks:
#  ['Adda', 'Silver Streak', 'Mainland China', 'Chill Ummm', 'Tyre Patty']
# -----------------------------------------
# For Coimbatore :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Valarmathi Kongunaatu Samayal', "That's Y Food", 'Haribhavanam Hotel', 'The Cascade Restaurant']
# -----------------------------------------
# For Mangalore :
#
# Total Restaurants:  20
# Best Restaurant: Froth On Top
#
# Top 5 Restaurants in order of their ranks:
#  ['Froth On Top', "Sizzler's Ranch", "Giri Manja's", 'Liquid Lounge', 'Machali']
# -----------------------------------------
# For Vadodara :
#
# Total Restaurants:  20
# Best Restaurant: Tomato's
#
# Top 5 Restaurants in order of their ranks:
#  ["Tomato's", '22nd Parallel', 'La Quello - Mediterranean Kitchen', 'Barbeque Nation', 'That Place']
# -----------------------------------------
# For Nagpur :
#
# Total Restaurants:  20
# Best Restaurant: The Breakfast Story
#
# Top 5 Restaurants in order of their ranks:
#  ['The Breakfast Story', 'Ten Downing Street Restaurant & Bar', 'FSB', 'Ashoka Restaurant', 'Mocha']
# -----------------------------------------
# For Agra :
#
# Total Restaurants:  20
# Best Restaurant: Pinch Of Spice
#
# Top 5 Restaurants in order of their ranks:
#  ['Pinch Of Spice', "Tea'se Me - Rooftop Tea Boutique", 'Thaaliwala', 'Pind Balluchi', 'Pizza Hut']
# -----------------------------------------
# For Dehradun :
#
# Total Restaurants:  20
# Best Restaurant: Kalsang Friends Corner
#
# Top 5 Restaurants in order of their ranks:
#  ['Kalsang Friends Corner', 'TBistro', 'Black Pepper Restaurant', 'Town Table Restaurant', 'Anandam']
# -----------------------------------------
# For Mysore :
#
# Total Restaurants:  20
# Best Restaurant: Vinayaka Mylari
#
# Top 5 Restaurants in order of their ranks:
#  ['Vinayaka Mylari', 'Empire Restaurant', 'Pizza Hut', 'Barbeque Nation', 'The Old House']
# -----------------------------------------
# For Puducherry :
#
# Total Restaurants:  20
# Best Restaurant: Baker Street
#
# Top 5 Restaurants in order of their ranks:
#  ['Baker Street', 'Zuka Choco-la', 'Le Cafe', 'Villa Shanti', 'Tanto Pizzeria']
# -----------------------------------------
# For Surat :
#
# Total Restaurants:  20
# Best Restaurant: Falafel Lovers
#
# Top 5 Restaurants in order of their ranks:
#  ['Falafel Lovers', 'Leonardo Italian Mediterranean Dining', 'Mysore Cafe', 'Black Pepper', 'Coffee Culture - The Ristorante Lounge']
# -----------------------------------------
# For Varanasi :
#
# Total Restaurants:  20
# Best Restaurant: Kashi Chat Bhandar
#
# Top 5 Restaurants in order of their ranks:
#  ['Kashi Chat Bhandar', 'Ming Garden', 'Pizzeria Vaatika Cafe', 'Kerala Cafe', 'VNS Live Studio']
# -----------------------------------------
# For Patna :
#
# Total Restaurants:  20
# Best Restaurant: Pind Balluchi
#
# Top 5 Restaurants in order of their ranks:
#  ['Pind Balluchi', '17 Degrees', 'The Yellow Chilli', "Kapil Dev's Eleven", 'Bansi Vihar']
# -----------------------------------------
# For Dubai :
#
# Total Restaurants:  20
# Best Restaurant: AB's Absolute Barbecues
#
# Top 5 Restaurants in order of their ranks:
#  ["AB's Absolute Barbecues", 'The Cheesecake Factory', 'Tresind - Nassima Royal Hotel', 'Hard Rock Cafe', 'Maharaja Bhog']
# -----------------------------------------
# For Singapore :
#
# Total Restaurants:  19
# Best Restaurant: Fratini La Trattoria
#
# Top 5 Restaurants in order of their ranks:
#  ['Fratini La Trattoria', 'Bitters & Love', 'Jaan', 'Summer Pavilion', 'Cut By Wolfgang Puck']
# -----------------------------------------
# For Sharjah :
#
# Total Restaurants:  20
# Best Restaurant: Rajasthan Al Malaki
#
# Top 5 Restaurants in order of their ranks:
#  ['Rajasthan Al Malaki', 'Najmat Lahore Restaurant', 'Aroos Damascus', 'Nayaab Haandi', 'Gazebo']
# -----------------------------------------
# For Abu Dhabi :
#
# Total Restaurants:  20
# Best Restaurant: The Cheesecake Factory
#
# Top 5 Restaurants in order of their ranks:
#  ['The Cheesecake Factory', 'Via Delhi', 'Pizza Di Rocco', "P.F. Chang's", 'Olive Garden']
# -----------------------------------------
# For Colombo :
#
# Total Restaurants:  20
# Best Restaurant: The Sizzle
#
# Top 5 Restaurants in order of their ranks:
#  ['The Sizzle', 'Ministry of Crab', 'The Commons', "Burger's King", 'The Manhattan Fish Market']
# -----------------------------------------
# For İstanbul :
#
# Total Restaurants:  20
# Best Restaurant: J'adore Chocolatier
#
# Top 5 Restaurants in order of their ranks:
#  ["J'adore Chocolatier", 'Karaköy Güllüoğlu', 'Bayramoğlu Döner', 'Starbucks', 'Ceviz Ağacı']
# -----------------------------------------
# For Ankara :
#
# Total Restaurants:  20
# Best Restaurant: Çukurağa Sofrası
#
# Top 5 Restaurants in order of their ranks:
#  ['Çukurağa Sofrası', 'Meşhur Tavacı Recep Usta', 'Masabaşı Kebapçısı', 'Düveroğlu', 'Düveroğlu']
# -----------------------------------------
# For London :
#
# Total Restaurants:  20
# Best Restaurant: Yauatcha
#
# Top 5 Restaurants in order of their ranks:
#  ['Yauatcha', 'Dishoom', 'Duck & Waffle', 'Bocca Di Lupo', 'Roka']
# -----------------------------------------
# For Doha :
#
# Total Restaurants:  20
# Best Restaurant: Zaffran Dining Experience
#
# Top 5 Restaurants in order of their ranks:
#  ['Zaffran Dining Experience', 'MRA Bakery Sweets & Restaurant', 'Indian Coffee House', 'Aalishan', 'Gokul Gujarati Restaurant']
# -----------------------------------------
# For Makati City :
#
# Total Restaurants:  2
# Best Restaurant: Izakaya Kikufuji
#
# Top 2 Restaurants order of their ranks:
#  ['Izakaya Kikufuji', 'Le Petit Souffle']
# -----------------------------------------
# For Taguig City :
#
# Total Restaurants:  4
# Best Restaurant: The Food Hall by Todd English
#
# Top 4 Restaurants order of their ranks:
#  ['The Food Hall by Todd English', 'NIU by Vikings', 'Wildflour Cafe + Bakery', 'Hobing Korean Dessert Cafe']
# -----------------------------------------
# For Mandaluyong City :
#
# Total Restaurants:  4
# Best Restaurant: Ooma
#
# Top 4 Restaurants order of their ranks:
#  ['Ooma', 'Din Tai Fung', 'Heat - Edsa Shangri-La', 'Sambo Kojin']
# -----------------------------------------
# For Pasay City :
#
# Total Restaurants:  3
# Best Restaurant: Spiral - Sofitel Philippine Plaza Manila
#
# Top 3 Restaurants order of their ranks:
#  ['Spiral - Sofitel Philippine Plaza Manila', 'Vikings', 'Buffet 101']
# -----------------------------------------
# For Pasig City :
#
# Total Restaurants:  3
# Best Restaurant: Silantro Fil-Mex
#
# Top 3 Restaurants order of their ranks:
#  ['Silantro Fil-Mex', 'Locavore', "Mad Mark's Creamery & Good Eats"]
# -----------------------------------------
# For Quezon City :
#
# Total Restaurants:  1
# Best Restaurant: Silantro Fil-Mex
#
# Top 1 Restaurants order of their ranks:
#  ['Silantro Fil-Mex']
# -----------------------------------------
# For Tagaytay City :
#
# Total Restaurants:  1
# Best Restaurant: Balay Dako
#
# Top 1 Restaurants order of their ranks:
#  ['Balay Dako']
# -----------------------------------------
# For San Juan City :
#
# Total Restaurants:  2
# Best Restaurant: Guevarra's
#
# Top 2 Restaurants order of their ranks:
#  ["Guevarra's", 'Sodam Korean Restaurant']
# -----------------------------------------
# For Cape Town :
#
# Total Restaurants:  20
# Best Restaurant: Beluga
#
# Top 5 Restaurants in order of their ranks:
#  ['Beluga', 'Truth Coffee', 'Willoughby & Co.', 'Kloof Street House', 'tashas']
# -----------------------------------------
# For Sandton :
#
# Total Restaurants:  11
# Best Restaurant: Licorish Bistro
#
# Top 5 Restaurants in order of their ranks:
#  ['Licorish Bistro', 'Escondido Tapas', 'Gemelli Cucina Bar', 'Perron', 'Cafe Del Sol Botanico']
# -----------------------------------------
# For Johannesburg :
#
# Total Restaurants:  6
# Best Restaurant: Craft
#
# Top 5 Restaurants in order of their ranks:
#  ['Craft', 'The Wolfpack', 'Hudsons', 'Marble', 'The National']
# -----------------------------------------
# For Inner City :
#
# Total Restaurants:  2
# Best Restaurant: Cube - Tasting Kitchen
#
# Top 2 Restaurants order of their ranks:
#  ['Cube - Tasting Kitchen', 'Urbanologi']
# -----------------------------------------
# For Randburg :
#
# Total Restaurants:  1
# Best Restaurant: The Whippet
#
# Top 1 Restaurants order of their ranks:
#  ['The Whippet']
# -----------------------------------------
# For Brasília :
#
# Total Restaurants:  18
# Best Restaurant: Coco Bambu
#
# Top 5 Restaurants in order of their ranks:
#  ['Coco Bambu', 'Taco Pep', 'Coco Bambu', 'Villa Tevere', 'Maori']
# -----------------------------------------
# For São Paulo :
#
# Total Restaurants:  18
# Best Restaurant: Meats
#
# Top 5 Restaurants in order of their ranks:
#  ['Meats', 'Skye - Hotel Unique', 'Veloso', 'Paris 6 Classique', 'Cantina Famiglia Mancini']
# -----------------------------------------
# For Manchester :
#
# Total Restaurants:  20
# Best Restaurant: San Carlo
#
# Top 5 Restaurants in order of their ranks:
#  ['San Carlo', 'The Grill On The Alley', 'Gaucho', 'Chaophraya', 'Akbars']
# -----------------------------------------
# For Birmingham :
#
# Total Restaurants:  20
# Best Restaurant: Purnell's
#
# Top 5 Restaurants in order of their ranks:
#  ["Purnell's", 'Lasan Restaurant', 'San Carlo', 'Bank', 'Bodega']
# -----------------------------------------
# For Auckland :
#
# Total Restaurants:  20
# Best Restaurant: Milse
#
# Top 5 Restaurants in order of their ranks:
#  ['Milse', 'Federal Delicatessen', 'Giapo', 'Depot Eatery and Oyster Bar', 'Eight - The Langham Hotel']
# -----------------------------------------
# For Wellington City :
#
# Total Restaurants:  20
# Best Restaurant: Fidel's
#
# Top 5 Restaurants in order of their ranks:
#  ["Fidel's", 'The Crab Shack', 'Ekim Burgers', 'The Hangar', 'Floriditas']
# -----------------------------------------
# For Dummy :
#
# Total Restaurants:  1
# Best Restaurant: The Woodlands Eatery
#
# Top 1 Restaurants order of their ranks:
#  ['The Woodlands Eatery']
# -----------------------------------------
# For Rio de Janeiro :
#
# Total Restaurants:  19
# Best Restaurant: Garota de Ipanema
#
# Top 5 Restaurants in order of their ranks:
#  ['Garota de Ipanema', 'Aprazível', 'Braseiro da Gávea', 'Confeitaria Colombo', 'Cervantes']
# -----------------------------------------
# For Jakarta :
#
# Total Restaurants:  16
# Best Restaurant: Talaga Sampireun
#
# Top 5 Restaurants in order of their ranks:
#  ['Talaga Sampireun', 'Talaga Sampireun', 'Toodz House', 'Skye', 'Union Deli']
# -----------------------------------------
# For Bogor :
#
# Total Restaurants:  2
# Best Restaurant: Lemongrass
#
# Top 2 Restaurants order of their ranks:
#  ['Lemongrass', 'Momo Milk']
# -----------------------------------------
# For Tangerang :
#
# Total Restaurants:  2
# Best Restaurant: Talaga Sampireun
#
# Top 2 Restaurants order of their ranks:
#  ['Talaga Sampireun', 'Onokabe']
# -----------------------------------------
# For Pretoria :
#
# Total Restaurants:  20
# Best Restaurant: Kream
#
# Top 5 Restaurants in order of their ranks:
#  ['Kream', 'Capital Craft Beer Academy', 'Harissa Bistro', 'Hogshead', 'Life Grand Cafe']
# -----------------------------------------
# For Edinburgh :
#
# Total Restaurants:  20
# Best Restaurant: La Favorita
#
# Top 5 Restaurants in order of their ranks:
#  ['La Favorita', "Mother India's Cafe", 'The Kitchin', 'The Witchery & The Secret Garden', 'Roseleaf Bar Cafe']
# Enter Filename
# ->file2.json
# -----------------------------------------
# For New Delhi :
#
# Total Restaurants:  15
# Best Restaurant: Hauz Khas Social
#
# Top 5 Restaurants in order of their ranks:
#  ['Hauz Khas Social', 'Saravana Bhavan', 'My Bar Headquarters', 'Farzi Cafe', 'Odeon Social']
# -----------------------------------------
# For Gurgaon :
#
# Total Restaurants:  5
# Best Restaurant: Farzi Cafe
#
# Top 5 Restaurants in order of their ranks:
#  ['Farzi Cafe', 'Manhattan Brewery & Bar Exchange', 'Molecule Air Bar', 'The Wine Company', 'Indian Grill Room']
# -----------------------------------------
# For Kolkata :
#
# Total Restaurants:  20
# Best Restaurant: Peter Cat
#
# Top 5 Restaurants in order of their ranks:
#  ['Peter Cat', 'Barbeque Nation', 'BarBQ', 'Mocambo', "Santa's Fantasea"]
# -----------------------------------------
# For Mumbai :
#
# Total Restaurants:  20
# Best Restaurant: Joey's Pizza
#
# Top 5 Restaurants in order of their ranks:
#  ["Joey's Pizza", 'Mirchi And Mime', 'SpiceKlub', "Joey's Pizza", 'The Fusion Kitchen']
# -----------------------------------------
# For Bangalore :
#
# Total Restaurants:  20
# Best Restaurant: Toit
#
# Top 5 Restaurants in order of their ranks:
#  ['Toit', 'Truffles', "AB's - Absolute Barbecues", 'Big Brewsky', 'The Black Pearl']
# -----------------------------------------
# For Pune :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Le Plaisir', 'Effingut Brewerkz', "Chili's", "Agent Jack's Bar"]
# -----------------------------------------
# For Hyderabad :
#
# Total Restaurants:  18
# Best Restaurant: AB's - Absolute Barbecues
#
# Top 5 Restaurants in order of their ranks:
#  ["AB's - Absolute Barbecues", 'Exotica', "Chili's", 'Olive Bistro', "Chili's"]
# -----------------------------------------
# For Secunderabad :
#
# Total Restaurants:  2
# Best Restaurant: Coffee Cup
#
# Top 2 Restaurants order of their ranks:
#  ['Coffee Cup', 'Saffron Mantra']
# -----------------------------------------
# For Chennai :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Pind', 'Bombay Brasserie', 'That Madras Place', 'Kaidi Kitchen']
# -----------------------------------------
# For Lucknow :
#
# Total Restaurants:  20
# Best Restaurant: Grandson of Tunday Kababi
#
# Top 5 Restaurants in order of their ranks:
#  ['Grandson of Tunday Kababi', 'Barbeque Nation', 'Vintage Machine', 'Dastarkhwan', 'Royal Sky']
# -----------------------------------------
# For Kochi :
#
# Total Restaurants:  20
# Best Restaurant: Paragon
#
# Top 5 Restaurants in order of their ranks:
#  ['Paragon', 'Dhe Puttu', 'Cocoa Tree', 'Kashi Art Cafe', "Bloomsbury's Boutique Cafe and Artisan Bakery"]
# -----------------------------------------
# For Jaipur :
#
# Total Restaurants:  20
# Best Restaurant: Tapri Central
#
# Top 5 Restaurants in order of their ranks:
#  ['Tapri Central', 'Chokhi Dhani', 'Replay', 'On The House', 'The Forresta Kitchen & Bar']
# -----------------------------------------
# For Ahmedabad :
#
# Total Restaurants:  20
# Best Restaurant: 650 - The Global Kitchen
#
# Top 5 Restaurants in order of their ranks:
#  ['650 - The Global Kitchen', "Nini's Kitchen", 'Patang - The Revolving Restaurant', 'Yanki Sizzlers', 'Mocha']
# -----------------------------------------
# For Chandigarh :
#
# Total Restaurants:  18
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', "Chili's", 'Pirates of Grill', 'Pal Dhaba', 'Virgin Courtyard']
# -----------------------------------------
# For Mohali :
#
# Total Restaurants:  1
# Best Restaurant: The Shooters Cafe
#
# Top 1 Restaurants order of their ranks:
#  ['The Shooters Cafe']
# -----------------------------------------
# For Panchkula :
#
# Total Restaurants:  1
# Best Restaurant: Hops n Grains
#
# Top 1 Restaurants order of their ranks:
#  ['Hops n Grains']
# -----------------------------------------
# For Goa :
#
# Total Restaurants:  20
# Best Restaurant: Britto's Bar & Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ["Britto's Bar & Restaurant", 'Curlies', "Martin's Corner", 'Infantaria', 'Souza Lobo']
# -----------------------------------------
# For Indore :
#
# Total Restaurants:  20
# Best Restaurant: Nafees Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ['Nafees Restaurant', 'Cafe Terazza', 'Mangosteen Cafe', '10 Downing Street', 'Vidorra']
# -----------------------------------------
# For Nashik :
#
# Total Restaurants:  20
# Best Restaurant: Sadhana Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ['Sadhana Restaurant', 'Barbeque Ville', 'Enter The Dragon', 'Al Arabian Express', 'RiverDine Restaurant & Bar']
# -----------------------------------------
# For Ludhiana :
#
# Total Restaurants:  20
# Best Restaurant: The Yellow Chilli
#
# Top 5 Restaurants in order of their ranks:
#  ['The Yellow Chilli', 'Hot Breads', 'Bistro 226', 'Aman Chicken', 'Nik Bakers']
# -----------------------------------------
# For Guwahati :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Mocha', 'Chung Fa', 'Terra Mayaa Restaurant and Lounge', 'Confucius']
# -----------------------------------------
# For Amritsar :
#
# Total Restaurants:  20
# Best Restaurant: Bharawan Da Dhaba
#
# Top 5 Restaurants in order of their ranks:
#  ['Bharawan Da Dhaba', 'Makhan Fish and Chicken Corner', 'Brothers Dhaba', 'The Kulcha Land', 'Beera Chicken Corner']
# -----------------------------------------
# For Kanpur :
#
# Total Restaurants:  19
# Best Restaurant: Aromas
#
# Top 5 Restaurants in order of their ranks:
#  ['Aromas', 'Dhuaan', 'Little Chef', 'Verandah', 'UrbanCrave']
# -----------------------------------------
# For Allahabad :
#
# Total Restaurants:  20
# Best Restaurant: Tandoor Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ['Tandoor Restaurant', 'Sagar Ratna', 'Eat On', 'Hot Stuff', 'The Tamarind Tree']
# -----------------------------------------
# For Aurangabad :
#
# Total Restaurants:  20
# Best Restaurant: Kream N Krunch
#
# Top 5 Restaurants in order of their ranks:
#  ['Kream N Krunch', 'Bhoj Restaurant', 'Madhuban Restaurant - Welcome Hotel Rama International', "d' Curry House", 'Indiana Veg Restaurant']
# -----------------------------------------
# For Bhopal :
#
# Total Restaurants:  20
# Best Restaurant: Sagar Gaire Fast Food
#
# Top 5 Restaurants in order of their ranks:
#  ['Sagar Gaire Fast Food', 'Manohar Dairy And Restaurant', '10 Downing Street', 'Manohar Dairy And Restaurant', 'Bake N Shake']
# -----------------------------------------
# For Ranchi :
#
# Total Restaurants:  20
# Best Restaurant: Kaveri Restaurant And Caterers
#
# Top 5 Restaurants in order of their ranks:
#  ['Kaveri Restaurant And Caterers', 'Yellow Sapphire', 'Moti Mahal Delux Tandoori Trail', 'KFC', 'Yo China Restaurant']
# -----------------------------------------
# For Vizag :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Flying Spaghetti Monster', 'Pizza Hut', 'Sri Sairam Parlour', 'Pizza Hut']
# -----------------------------------------
# For Bhubaneshwar :
#
# Total Restaurants:  20
# Best Restaurant: Adda
#
# Top 5 Restaurants in order of their ranks:
#  ['Adda', 'Silver Streak', 'Mainland China', 'Chill Ummm', 'Tyre Patty']
# -----------------------------------------
# For Coimbatore :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Valarmathi Kongunaatu Samayal', "That's Y Food", 'Haribhavanam Hotel', 'The Cascade Restaurant']
# -----------------------------------------
# For Mangalore :
#
# Total Restaurants:  20
# Best Restaurant: Froth On Top
#
# Top 5 Restaurants in order of their ranks:
#  ['Froth On Top', "Sizzler's Ranch", "Giri Manja's", 'Liquid Lounge', 'Machali']
# -----------------------------------------
# For Vadodara :
#
# Total Restaurants:  20
# Best Restaurant: Tomato's
#
# Top 5 Restaurants in order of their ranks:
#  ["Tomato's", '22nd Parallel', 'La Quello - Mediterranean Kitchen', 'Barbeque Nation', 'That Place']
# -----------------------------------------
# For Nagpur :
#
# Total Restaurants:  20
# Best Restaurant: The Breakfast Story
#
# Top 5 Restaurants in order of their ranks:
#  ['The Breakfast Story', 'Ten Downing Street Restaurant & Bar', 'FSB', 'Ashoka Restaurant', 'Mocha']
# -----------------------------------------
# For Agra :
#
# Total Restaurants:  20
# Best Restaurant: Pinch Of Spice
#
# Top 5 Restaurants in order of their ranks:
#  ['Pinch Of Spice', "Tea'se Me - Rooftop Tea Boutique", 'Thaaliwala', 'Pind Balluchi', 'Pizza Hut']
# -----------------------------------------
# For Dehradun :
#
# Total Restaurants:  20
# Best Restaurant: Kalsang Friends Corner
#
# Top 5 Restaurants in order of their ranks:
#  ['Kalsang Friends Corner', 'TBistro', 'Black Pepper Restaurant', 'Town Table Restaurant', 'Anandam']
# -----------------------------------------
# For Mysore :
#
# Total Restaurants:  20
# Best Restaurant: Vinayaka Mylari
#
# Top 5 Restaurants in order of their ranks:
#  ['Vinayaka Mylari', 'Empire Restaurant', 'Pizza Hut', 'Barbeque Nation', 'The Old House']
# -----------------------------------------
# For Puducherry :
#
# Total Restaurants:  20
# Best Restaurant: Baker Street
#
# Top 5 Restaurants in order of their ranks:
#  ['Baker Street', 'Zuka Choco-la', 'Le Cafe', 'Villa Shanti', 'Tanto Pizzeria']
# -----------------------------------------
# For Surat :
#
# Total Restaurants:  20
# Best Restaurant: Falafel Lovers
#
# Top 5 Restaurants in order of their ranks:
#  ['Falafel Lovers', 'Leonardo Italian Mediterranean Dining', 'Mysore Cafe', 'Black Pepper', 'Coffee Culture - The Ristorante Lounge']
# -----------------------------------------
# For Varanasi :
#
# Total Restaurants:  20
# Best Restaurant: Kashi Chat Bhandar
#
# Top 5 Restaurants in order of their ranks:
#  ['Kashi Chat Bhandar', 'Ming Garden', 'Pizzeria Vaatika Cafe', 'Kerala Cafe', 'VNS Live Studio']
# -----------------------------------------
# For Patna :
#
# Total Restaurants:  20
# Best Restaurant: Pind Balluchi
#
# Top 5 Restaurants in order of their ranks:
#  ['Pind Balluchi', '17 Degrees', 'The Yellow Chilli', "Kapil Dev's Eleven", 'Bansi Vihar']
# -----------------------------------------
# For Dubai :
#
# Total Restaurants:  20
# Best Restaurant: AB's Absolute Barbecues
#
# Top 5 Restaurants in order of their ranks:
#  ["AB's Absolute Barbecues", 'The Cheesecake Factory', 'Tresind - Nassima Royal Hotel', 'Hard Rock Cafe', 'Maharaja Bhog']
# -----------------------------------------
# For Singapore :
#
# Total Restaurants:  19
# Best Restaurant: Fratini La Trattoria
#
# Top 5 Restaurants in order of their ranks:
#  ['Fratini La Trattoria', 'Bitters & Love', 'Jaan', 'Summer Pavilion', 'Cut By Wolfgang Puck']
# -----------------------------------------
# For Sharjah :
#
# Total Restaurants:  20
# Best Restaurant: Rajasthan Al Malaki
#
# Top 5 Restaurants in order of their ranks:
#  ['Rajasthan Al Malaki', 'Najmat Lahore Restaurant', 'Aroos Damascus', 'Nayaab Haandi', 'Gazebo']
# -----------------------------------------
# For Abu Dhabi :
#
# Total Restaurants:  20
# Best Restaurant: The Cheesecake Factory
#
# Top 5 Restaurants in order of their ranks:
#  ['The Cheesecake Factory', 'Via Delhi', 'Pizza Di Rocco', "P.F. Chang's", 'Olive Garden']
# -----------------------------------------
# For Colombo :
#
# Total Restaurants:  20
# Best Restaurant: The Sizzle
#
# Top 5 Restaurants in order of their ranks:
#  ['The Sizzle', 'Ministry of Crab', 'The Commons', "Burger's King", 'The Manhattan Fish Market']
# -----------------------------------------
# For İstanbul :
#
# Total Restaurants:  20
# Best Restaurant: J'adore Chocolatier
#
# Top 5 Restaurants in order of their ranks:
#  ["J'adore Chocolatier", 'Karaköy Güllüoğlu', 'Bayramoğlu Döner', 'Starbucks', 'Ceviz Ağacı']
# -----------------------------------------
# For Ankara :
#
# Total Restaurants:  20
# Best Restaurant: Çukurağa Sofrası
#
# Top 5 Restaurants in order of their ranks:
#  ['Çukurağa Sofrası', 'Meşhur Tavacı Recep Usta', 'Masabaşı Kebapçısı', 'Düveroğlu', 'Düveroğlu']
# -----------------------------------------
# For London :
#
# Total Restaurants:  20
# Best Restaurant: Yauatcha
#
# Top 5 Restaurants in order of their ranks:
#  ['Yauatcha', 'Dishoom', 'Duck & Waffle', 'Bocca Di Lupo', 'Roka']
# -----------------------------------------
# For Doha :
#
# Total Restaurants:  20
# Best Restaurant: Zaffran Dining Experience
#
# Top 5 Restaurants in order of their ranks:
#  ['Zaffran Dining Experience', 'MRA Bakery Sweets & Restaurant', 'Indian Coffee House', 'Aalishan', 'Gokul Gujarati Restaurant']
# -----------------------------------------
# For Makati City :
#
# Total Restaurants:  2
# Best Restaurant: Izakaya Kikufuji
#
# Top 2 Restaurants order of their ranks:
#  ['Izakaya Kikufuji', 'Le Petit Souffle']
# -----------------------------------------
# For Taguig City :
#
# Total Restaurants:  4
# Best Restaurant: The Food Hall by Todd English
#
# Top 4 Restaurants order of their ranks:
#  ['The Food Hall by Todd English', 'NIU by Vikings', 'Wildflour Cafe + Bakery', 'Hobing Korean Dessert Cafe']
# -----------------------------------------
# For Mandaluyong City :
#
# Total Restaurants:  4
# Best Restaurant: Ooma
#
# Top 4 Restaurants order of their ranks:
#  ['Ooma', 'Din Tai Fung', 'Heat - Edsa Shangri-La', 'Sambo Kojin']
# -----------------------------------------
# For Pasay City :
#
# Total Restaurants:  3
# Best Restaurant: Spiral - Sofitel Philippine Plaza Manila
#
# Top 3 Restaurants order of their ranks:
#  ['Spiral - Sofitel Philippine Plaza Manila', 'Vikings', 'Buffet 101']
# -----------------------------------------
# For Pasig City :
#
# Total Restaurants:  3
# Best Restaurant: Silantro Fil-Mex
#
# Top 3 Restaurants order of their ranks:
#  ['Silantro Fil-Mex', 'Locavore', "Mad Mark's Creamery & Good Eats"]
# -----------------------------------------
# For Quezon City :
#
# Total Restaurants:  1
# Best Restaurant: Silantro Fil-Mex
#
# Top 1 Restaurants order of their ranks:
#  ['Silantro Fil-Mex']
# -----------------------------------------
# For Tagaytay City :
#
# Total Restaurants:  1
# Best Restaurant: Balay Dako
#
# Top 1 Restaurants order of their ranks:
#  ['Balay Dako']
# -----------------------------------------
# For San Juan City :
#
# Total Restaurants:  2
# Best Restaurant: Guevarra's
#
# Top 2 Restaurants order of their ranks:
#  ["Guevarra's", 'Sodam Korean Restaurant']
# -----------------------------------------
# For Cape Town :
#
# Total Restaurants:  20
# Best Restaurant: Beluga
#
# Top 5 Restaurants in order of their ranks:
#  ['Beluga', 'Truth Coffee', 'Willoughby & Co.', 'Kloof Street House', 'tashas']
# -----------------------------------------
# For Sandton :
#
# Total Restaurants:  11
# Best Restaurant: Licorish Bistro
#
# Top 5 Restaurants in order of their ranks:
#  ['Licorish Bistro', 'Escondido Tapas', 'Gemelli Cucina Bar', 'Perron', 'Cafe Del Sol Botanico']
# -----------------------------------------
# For Johannesburg :
#
# Total Restaurants:  6
# Best Restaurant: Craft
#
# Top 5 Restaurants in order of their ranks:
#  ['Craft', 'The Wolfpack', 'Hudsons', 'Marble', 'The National']
# -----------------------------------------
# For Inner City :
#
# Total Restaurants:  2
# Best Restaurant: Cube - Tasting Kitchen
#
# Top 2 Restaurants order of their ranks:
#  ['Cube - Tasting Kitchen', 'Urbanologi']
# -----------------------------------------
# For Randburg :
#
# Total Restaurants:  1
# Best Restaurant: The Whippet
#
# Top 1 Restaurants order of their ranks:
#  ['The Whippet']
# -----------------------------------------
# For Brasília :
#
# Total Restaurants:  18
# Best Restaurant: Coco Bambu
#
# Top 5 Restaurants in order of their ranks:
#  ['Coco Bambu', 'Taco Pep', 'Coco Bambu', 'Villa Tevere', 'Maori']
# -----------------------------------------
# For São Paulo :
#
# Total Restaurants:  18
# Best Restaurant: Meats
#
# Top 5 Restaurants in order of their ranks:
#  ['Meats', 'Skye - Hotel Unique', 'Veloso', 'Paris 6 Classique', 'Cantina Famiglia Mancini']
# -----------------------------------------
# For Manchester :
#
# Total Restaurants:  20
# Best Restaurant: San Carlo
#
# Top 5 Restaurants in order of their ranks:
#  ['San Carlo', 'The Grill On The Alley', 'Gaucho', 'Chaophraya', 'Akbars']
# -----------------------------------------
# For Birmingham :
#
# Total Restaurants:  20
# Best Restaurant: Purnell's
#
# Top 5 Restaurants in order of their ranks:
#  ["Purnell's", 'Lasan Restaurant', 'San Carlo', 'Bank', 'Bodega']
# -----------------------------------------
# For Auckland :
#
# Total Restaurants:  20
# Best Restaurant: Milse
#
# Top 5 Restaurants in order of their ranks:
#  ['Milse', 'Federal Delicatessen', 'Giapo', 'Depot Eatery and Oyster Bar', 'Eight - The Langham Hotel']
# -----------------------------------------
# For Wellington City :
#
# Total Restaurants:  20
# Best Restaurant: Fidel's
#
# Top 5 Restaurants in order of their ranks:
#  ["Fidel's", 'The Crab Shack', 'Ekim Burgers', 'The Hangar', 'Floriditas']
# -----------------------------------------
# For Dummy :
#
# Total Restaurants:  1
# Best Restaurant: The Woodlands Eatery
#
# Top 1 Restaurants order of their ranks:
#  ['The Woodlands Eatery']
# -----------------------------------------
# For Rio de Janeiro :
#
# Total Restaurants:  19
# Best Restaurant: Garota de Ipanema
#
# Top 5 Restaurants in order of their ranks:
#  ['Garota de Ipanema', 'Aprazível', 'Braseiro da Gávea', 'Confeitaria Colombo', 'Cervantes']
# -----------------------------------------
# For Jakarta :
#
# Total Restaurants:  16
# Best Restaurant: Talaga Sampireun
#
# Top 5 Restaurants in order of their ranks:
#  ['Talaga Sampireun', 'Talaga Sampireun', 'Toodz House', 'Skye', 'Union Deli']
# -----------------------------------------
# For Bogor :
#
# Total Restaurants:  2
# Best Restaurant: Lemongrass
#
# Top 2 Restaurants order of their ranks:
#  ['Lemongrass', 'Momo Milk']
# -----------------------------------------
# For Tangerang :
#
# Total Restaurants:  2
# Best Restaurant: Talaga Sampireun
#
# Top 2 Restaurants order of their ranks:
#  ['Talaga Sampireun', 'Onokabe']
# -----------------------------------------
# For Pretoria :
#
# Total Restaurants:  20
# Best Restaurant: Kream
#
# Top 5 Restaurants in order of their ranks:
#  ['Kream', 'Capital Craft Beer Academy', 'Harissa Bistro', 'Hogshead', 'Life Grand Cafe']
# -----------------------------------------
# For Edinburgh :
#
# Total Restaurants:  20
# Best Restaurant: La Favorita
#
# Top 5 Restaurants in order of their ranks:
#  ['La Favorita', "Mother India's Cafe", 'The Kitchin', 'The Witchery & The Secret Garden', 'Roseleaf Bar Cafe']
# Enter Filename
# ->file3.json
# -----------------------------------------
# For New Delhi :
#
# Total Restaurants:  15
# Best Restaurant: Hauz Khas Social
#
# Top 5 Restaurants in order of their ranks:
#  ['Hauz Khas Social', 'Saravana Bhavan', 'My Bar Headquarters', 'Farzi Cafe', 'Odeon Social']
# -----------------------------------------
# For Gurgaon :
#
# Total Restaurants:  5
# Best Restaurant: Farzi Cafe
#
# Top 5 Restaurants in order of their ranks:
#  ['Farzi Cafe', 'Manhattan Brewery & Bar Exchange', 'Molecule Air Bar', 'The Wine Company', 'Indian Grill Room']
# -----------------------------------------
# For Kolkata :
#
# Total Restaurants:  20
# Best Restaurant: Peter Cat
#
# Top 5 Restaurants in order of their ranks:
#  ['Peter Cat', 'Barbeque Nation', 'BarBQ', 'Mocambo', "Santa's Fantasea"]
# -----------------------------------------
# For Mumbai :
#
# Total Restaurants:  20
# Best Restaurant: Joey's Pizza
#
# Top 5 Restaurants in order of their ranks:
#  ["Joey's Pizza", 'Mirchi And Mime', 'SpiceKlub', "Joey's Pizza", 'The Fusion Kitchen']
# -----------------------------------------
# For Bangalore :
#
# Total Restaurants:  20
# Best Restaurant: Toit
#
# Top 5 Restaurants in order of their ranks:
#  ['Toit', 'Truffles', "AB's - Absolute Barbecues", 'Big Brewsky', 'The Black Pearl']
# -----------------------------------------
# For Pune :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Le Plaisir', 'Effingut Brewerkz', "Chili's", "Agent Jack's Bar"]
# -----------------------------------------
# For Hyderabad :
#
# Total Restaurants:  18
# Best Restaurant: AB's - Absolute Barbecues
#
# Top 5 Restaurants in order of their ranks:
#  ["AB's - Absolute Barbecues", 'Exotica', "Chili's", 'Olive Bistro', "Chili's"]
# -----------------------------------------
# For Secunderabad :
#
# Total Restaurants:  2
# Best Restaurant: Coffee Cup
#
# Top 2 Restaurants order of their ranks:
#  ['Coffee Cup', 'Saffron Mantra']
# -----------------------------------------
# For Chennai :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Pind', 'Bombay Brasserie', 'That Madras Place', 'Kaidi Kitchen']
# -----------------------------------------
# For Lucknow :
#
# Total Restaurants:  20
# Best Restaurant: Grandson of Tunday Kababi
#
# Top 5 Restaurants in order of their ranks:
#  ['Grandson of Tunday Kababi', 'Barbeque Nation', 'Vintage Machine', 'Dastarkhwan', 'Royal Sky']
# -----------------------------------------
# For Kochi :
#
# Total Restaurants:  20
# Best Restaurant: Paragon
#
# Top 5 Restaurants in order of their ranks:
#  ['Paragon', 'Dhe Puttu', 'Cocoa Tree', 'Kashi Art Cafe', "Bloomsbury's Boutique Cafe and Artisan Bakery"]
# -----------------------------------------
# For Jaipur :
#
# Total Restaurants:  20
# Best Restaurant: Tapri Central
#
# Top 5 Restaurants in order of their ranks:
#  ['Tapri Central', 'Chokhi Dhani', 'Replay', 'On The House', 'The Forresta Kitchen & Bar']
# -----------------------------------------
# For Ahmedabad :
#
# Total Restaurants:  20
# Best Restaurant: 650 - The Global Kitchen
#
# Top 5 Restaurants in order of their ranks:
#  ['650 - The Global Kitchen', "Nini's Kitchen", 'Patang - The Revolving Restaurant', 'Yanki Sizzlers', 'Mocha']
# -----------------------------------------
# For Chandigarh :
#
# Total Restaurants:  18
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', "Chili's", 'Pirates of Grill', 'Pal Dhaba', 'Virgin Courtyard']
# -----------------------------------------
# For Mohali :
#
# Total Restaurants:  1
# Best Restaurant: The Shooters Cafe
#
# Top 1 Restaurants order of their ranks:
#  ['The Shooters Cafe']
# -----------------------------------------
# For Panchkula :
#
# Total Restaurants:  1
# Best Restaurant: Hops n Grains
#
# Top 1 Restaurants order of their ranks:
#  ['Hops n Grains']
# -----------------------------------------
# For Goa :
#
# Total Restaurants:  20
# Best Restaurant: Britto's Bar & Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ["Britto's Bar & Restaurant", 'Curlies', "Martin's Corner", 'Infantaria', 'Souza Lobo']
# -----------------------------------------
# For Indore :
#
# Total Restaurants:  20
# Best Restaurant: Nafees Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ['Nafees Restaurant', 'Cafe Terazza', 'Mangosteen Cafe', '10 Downing Street', 'Vidorra']
# -----------------------------------------
# For Nashik :
#
# Total Restaurants:  20
# Best Restaurant: Sadhana Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ['Sadhana Restaurant', 'Barbeque Ville', 'Enter The Dragon', 'Al Arabian Express', 'RiverDine Restaurant & Bar']
# -----------------------------------------
# For Ludhiana :
#
# Total Restaurants:  20
# Best Restaurant: The Yellow Chilli
#
# Top 5 Restaurants in order of their ranks:
#  ['The Yellow Chilli', 'Hot Breads', 'Bistro 226', 'Aman Chicken', 'Nik Bakers']
# -----------------------------------------
# For Guwahati :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Mocha', 'Chung Fa', 'Terra Mayaa Restaurant and Lounge', 'Confucius']
# -----------------------------------------
# For Amritsar :
#
# Total Restaurants:  20
# Best Restaurant: Bharawan Da Dhaba
#
# Top 5 Restaurants in order of their ranks:
#  ['Bharawan Da Dhaba', 'Makhan Fish and Chicken Corner', 'Brothers Dhaba', 'The Kulcha Land', 'Beera Chicken Corner']
# -----------------------------------------
# For Kanpur :
#
# Total Restaurants:  19
# Best Restaurant: Aromas
#
# Top 5 Restaurants in order of their ranks:
#  ['Aromas', 'Dhuaan', 'Little Chef', 'Verandah', 'UrbanCrave']
# -----------------------------------------
# For Allahabad :
#
# Total Restaurants:  20
# Best Restaurant: Tandoor Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ['Tandoor Restaurant', 'Sagar Ratna', 'Eat On', 'Hot Stuff', 'The Tamarind Tree']
# -----------------------------------------
# For Aurangabad :
#
# Total Restaurants:  20
# Best Restaurant: Kream N Krunch
#
# Top 5 Restaurants in order of their ranks:
#  ['Kream N Krunch', 'Bhoj Restaurant', 'Madhuban Restaurant - Welcome Hotel Rama International', "d' Curry House", 'Indiana Veg Restaurant']
# -----------------------------------------
# For Bhopal :
#
# Total Restaurants:  20
# Best Restaurant: Sagar Gaire Fast Food
#
# Top 5 Restaurants in order of their ranks:
#  ['Sagar Gaire Fast Food', 'Manohar Dairy And Restaurant', '10 Downing Street', 'Manohar Dairy And Restaurant', 'Bake N Shake']
# -----------------------------------------
# For Ranchi :
#
# Total Restaurants:  20
# Best Restaurant: Kaveri Restaurant And Caterers
#
# Top 5 Restaurants in order of their ranks:
#  ['Kaveri Restaurant And Caterers', 'Yellow Sapphire', 'Moti Mahal Delux Tandoori Trail', 'KFC', 'Yo China Restaurant']
# -----------------------------------------
# For Vizag :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Flying Spaghetti Monster', 'Pizza Hut', 'Sri Sairam Parlour', 'Pizza Hut']
# -----------------------------------------
# For Bhubaneshwar :
#
# Total Restaurants:  20
# Best Restaurant: Adda
#
# Top 5 Restaurants in order of their ranks:
#  ['Adda', 'Silver Streak', 'Mainland China', 'Chill Ummm', 'Tyre Patty']
# -----------------------------------------
# For Coimbatore :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Valarmathi Kongunaatu Samayal', "That's Y Food", 'Haribhavanam Hotel', 'The Cascade Restaurant']
# -----------------------------------------
# For Mangalore :
#
# Total Restaurants:  20
# Best Restaurant: Froth On Top
#
# Top 5 Restaurants in order of their ranks:
#  ['Froth On Top', "Sizzler's Ranch", "Giri Manja's", 'Liquid Lounge', 'Machali']
# -----------------------------------------
# For Vadodara :
#
# Total Restaurants:  20
# Best Restaurant: Tomato's
#
# Top 5 Restaurants in order of their ranks:
#  ["Tomato's", '22nd Parallel', 'La Quello - Mediterranean Kitchen', 'Barbeque Nation', 'That Place']
# -----------------------------------------
# For Nagpur :
#
# Total Restaurants:  20
# Best Restaurant: The Breakfast Story
#
# Top 5 Restaurants in order of their ranks:
#  ['The Breakfast Story', 'Ten Downing Street Restaurant & Bar', 'FSB', 'Ashoka Restaurant', 'Mocha']
# -----------------------------------------
# For Agra :
#
# Total Restaurants:  20
# Best Restaurant: Pinch Of Spice
#
# Top 5 Restaurants in order of their ranks:
#  ['Pinch Of Spice', "Tea'se Me - Rooftop Tea Boutique", 'Thaaliwala', 'Pind Balluchi', 'Pizza Hut']
# -----------------------------------------
# For Dehradun :
#
# Total Restaurants:  20
# Best Restaurant: Kalsang Friends Corner
#
# Top 5 Restaurants in order of their ranks:
#  ['Kalsang Friends Corner', 'TBistro', 'Black Pepper Restaurant', 'Town Table Restaurant', 'Anandam']
# -----------------------------------------
# For Mysore :
#
# Total Restaurants:  20
# Best Restaurant: Vinayaka Mylari
#
# Top 5 Restaurants in order of their ranks:
#  ['Vinayaka Mylari', 'Empire Restaurant', 'Pizza Hut', 'Barbeque Nation', 'The Old House']
# -----------------------------------------
# For Puducherry :
#
# Total Restaurants:  20
# Best Restaurant: Baker Street
#
# Top 5 Restaurants in order of their ranks:
#  ['Baker Street', 'Zuka Choco-la', 'Le Cafe', 'Villa Shanti', 'Tanto Pizzeria']
# -----------------------------------------
# For Surat :
#
# Total Restaurants:  20
# Best Restaurant: Falafel Lovers
#
# Top 5 Restaurants in order of their ranks:
#  ['Falafel Lovers', 'Leonardo Italian Mediterranean Dining', 'Mysore Cafe', 'Black Pepper', 'Coffee Culture - The Ristorante Lounge']
# -----------------------------------------
# For Varanasi :
#
# Total Restaurants:  20
# Best Restaurant: Kashi Chat Bhandar
#
# Top 5 Restaurants in order of their ranks:
#  ['Kashi Chat Bhandar', 'Ming Garden', 'Pizzeria Vaatika Cafe', 'Kerala Cafe', 'VNS Live Studio']
# -----------------------------------------
# For Patna :
#
# Total Restaurants:  20
# Best Restaurant: Pind Balluchi
#
# Top 5 Restaurants in order of their ranks:
#  ['Pind Balluchi', '17 Degrees', 'The Yellow Chilli', "Kapil Dev's Eleven", 'Bansi Vihar']
# -----------------------------------------
# For Dubai :
#
# Total Restaurants:  20
# Best Restaurant: AB's Absolute Barbecues
#
# Top 5 Restaurants in order of their ranks:
#  ["AB's Absolute Barbecues", 'The Cheesecake Factory', 'Tresind - Nassima Royal Hotel', 'Hard Rock Cafe', 'Maharaja Bhog']
# -----------------------------------------
# For Singapore :
#
# Total Restaurants:  19
# Best Restaurant: Fratini La Trattoria
#
# Top 5 Restaurants in order of their ranks:
#  ['Fratini La Trattoria', 'Bitters & Love', 'Jaan', 'Summer Pavilion', 'Cut By Wolfgang Puck']
# -----------------------------------------
# For Sharjah :
#
# Total Restaurants:  20
# Best Restaurant: Rajasthan Al Malaki
#
# Top 5 Restaurants in order of their ranks:
#  ['Rajasthan Al Malaki', 'Najmat Lahore Restaurant', 'Aroos Damascus', 'Nayaab Haandi', 'Gazebo']
# -----------------------------------------
# For Abu Dhabi :
#
# Total Restaurants:  20
# Best Restaurant: The Cheesecake Factory
#
# Top 5 Restaurants in order of their ranks:
#  ['The Cheesecake Factory', 'Via Delhi', 'Pizza Di Rocco', "P.F. Chang's", 'Olive Garden']
# -----------------------------------------
# For Colombo :
#
# Total Restaurants:  20
# Best Restaurant: The Sizzle
#
# Top 5 Restaurants in order of their ranks:
#  ['The Sizzle', 'Ministry of Crab', 'The Commons', "Burger's King", 'The Manhattan Fish Market']
# -----------------------------------------
# For İstanbul :
#
# Total Restaurants:  20
# Best Restaurant: J'adore Chocolatier
#
# Top 5 Restaurants in order of their ranks:
# ...
# For Lucknow :
#
# Total Restaurants:  20
# Best Restaurant: Grandson of Tunday Kababi
#
# Top 5 Restaurants in order of their ranks:
#  ['Grandson of Tunday Kababi', 'Barbeque Nation', 'Vintage Machine', 'Dastarkhwan', 'Royal Sky']
# -----------------------------------------
# For Kochi :
#
# Total Restaurants:  20
# Best Restaurant: Paragon
#
# Top 5 Restaurants in order of their ranks:
#  ['Paragon', 'Dhe Puttu', 'Cocoa Tree', 'Kashi Art Cafe', "Bloomsbury's Boutique Cafe and Artisan Bakery"]
# -----------------------------------------
# For Jaipur :
#
# Total Restaurants:  20
# Best Restaurant: Tapri Central
#
# Top 5 Restaurants in order of their ranks:
#  ['Tapri Central', 'Chokhi Dhani', 'Replay', 'On The House', 'The Forresta Kitchen & Bar']
# -----------------------------------------
# For Ahmedabad :
#
# Total Restaurants:  20
# Best Restaurant: 650 - The Global Kitchen
#
# Top 5 Restaurants in order of their ranks:
#  ['650 - The Global Kitchen', "Nini's Kitchen", 'Patang - The Revolving Restaurant', 'Yanki Sizzlers', 'Mocha']
# -----------------------------------------
# For Chandigarh :
#
# Total Restaurants:  18
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', "Chili's", 'Pirates of Grill', 'Pal Dhaba', 'Virgin Courtyard']
# -----------------------------------------
# For Mohali :
#
# Total Restaurants:  1
# Best Restaurant: The Shooters Cafe
#
# Top 1 Restaurants order of their ranks:
#  ['The Shooters Cafe']
# -----------------------------------------
# For Panchkula :
#
# Total Restaurants:  1
# Best Restaurant: Hops n Grains
#
# Top 1 Restaurants order of their ranks:
#  ['Hops n Grains']
# -----------------------------------------
# For Goa :
#
# Total Restaurants:  20
# Best Restaurant: Britto's Bar & Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ["Britto's Bar & Restaurant", 'Curlies', "Martin's Corner", 'Infantaria', 'Souza Lobo']
# -----------------------------------------
# For Indore :
#
# Total Restaurants:  20
# Best Restaurant: Nafees Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ['Nafees Restaurant', 'Cafe Terazza', 'Mangosteen Cafe', '10 Downing Street', 'Vidorra']
# -----------------------------------------
# For Nashik :
#
# Total Restaurants:  20
# Best Restaurant: Sadhana Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ['Sadhana Restaurant', 'Barbeque Ville', 'Enter The Dragon', 'Al Arabian Express', 'RiverDine Restaurant & Bar']
# -----------------------------------------
# For Ludhiana :
#
# Total Restaurants:  20
# Best Restaurant: The Yellow Chilli
#
# Top 5 Restaurants in order of their ranks:
#  ['The Yellow Chilli', 'Hot Breads', 'Bistro 226', 'Aman Chicken', 'Nik Bakers']
# -----------------------------------------
# For Guwahati :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Mocha', 'Chung Fa', 'Terra Mayaa Restaurant and Lounge', 'Confucius']
# -----------------------------------------
# For Amritsar :
#
# Total Restaurants:  20
# Best Restaurant: Bharawan Da Dhaba
#
# Top 5 Restaurants in order of their ranks:
#  ['Bharawan Da Dhaba', 'Makhan Fish and Chicken Corner', 'Brothers Dhaba', 'The Kulcha Land', 'Beera Chicken Corner']
# -----------------------------------------
# For Kanpur :
#
# Total Restaurants:  19
# Best Restaurant: Aromas
#
# Top 5 Restaurants in order of their ranks:
#  ['Aromas', 'Dhuaan', 'Little Chef', 'Verandah', 'UrbanCrave']
# -----------------------------------------
# For Allahabad :
#
# Total Restaurants:  20
# Best Restaurant: Tandoor Restaurant
#
# Top 5 Restaurants in order of their ranks:
#  ['Tandoor Restaurant', 'Sagar Ratna', 'Eat On', 'Hot Stuff', 'The Tamarind Tree']
# -----------------------------------------
# For Aurangabad :
#
# Total Restaurants:  20
# Best Restaurant: Kream N Krunch
#
# Top 5 Restaurants in order of their ranks:
#  ['Kream N Krunch', 'Bhoj Restaurant', 'Madhuban Restaurant - Welcome Hotel Rama International', "d' Curry House", 'Indiana Veg Restaurant']
# -----------------------------------------
# For Bhopal :
#
# Total Restaurants:  20
# Best Restaurant: Sagar Gaire Fast Food
#
# Top 5 Restaurants in order of their ranks:
#  ['Sagar Gaire Fast Food', 'Manohar Dairy And Restaurant', '10 Downing Street', 'Manohar Dairy And Restaurant', 'Bake N Shake']
# -----------------------------------------
# For Ranchi :
#
# Total Restaurants:  20
# Best Restaurant: Kaveri Restaurant And Caterers
#
# Top 5 Restaurants in order of their ranks:
#  ['Kaveri Restaurant And Caterers', 'Yellow Sapphire', 'Moti Mahal Delux Tandoori Trail', 'KFC', 'Yo China Restaurant']
# -----------------------------------------
# For Vizag :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Flying Spaghetti Monster', 'Pizza Hut', 'Sri Sairam Parlour', 'Pizza Hut']
# -----------------------------------------
# For Bhubaneshwar :
#
# Total Restaurants:  20
# Best Restaurant: Adda
#
# Top 5 Restaurants in order of their ranks:
#  ['Adda', 'Silver Streak', 'Mainland China', 'Chill Ummm', 'Tyre Patty']
# -----------------------------------------
# For Coimbatore :
#
# Total Restaurants:  20
# Best Restaurant: Barbeque Nation
#
# Top 5 Restaurants in order of their ranks:
#  ['Barbeque Nation', 'Valarmathi Kongunaatu Samayal', "That's Y Food", 'Haribhavanam Hotel', 'The Cascade Restaurant']
# -----------------------------------------
# For Mangalore :
#
# Total Restaurants:  20
# Best Restaurant: Froth On Top
#
# Top 5 Restaurants in order of their ranks:
#  ['Froth On Top', "Sizzler's Ranch", "Giri Manja's", 'Liquid Lounge', 'Machali']
# -----------------------------------------
# For Vadodara :
#
# Total Restaurants:  20
# Best Restaurant: Tomato's
#
# Top 5 Restaurants in order of their ranks:
#  ["Tomato's", '22nd Parallel', 'La Quello - Mediterranean Kitchen', 'Barbeque Nation', 'That Place']
# -----------------------------------------
# For Nagpur :
#
# Total Restaurants:  20
# Best Restaurant: The Breakfast Story
#
# Top 5 Restaurants in order of their ranks:
#  ['The Breakfast Story', 'Ten Downing Street Restaurant & Bar', 'FSB', 'Ashoka Restaurant', 'Mocha']
# -----------------------------------------
# For Agra :
#
# Total Restaurants:  20
# Best Restaurant: Pinch Of Spice
#
# Top 5 Restaurants in order of their ranks:
#  ['Pinch Of Spice', "Tea'se Me - Rooftop Tea Boutique", 'Thaaliwala', 'Pind Balluchi', 'Pizza Hut']
# -----------------------------------------
# For Dehradun :
#
# Total Restaurants:  20
# Best Restaurant: Kalsang Friends Corner
#
# Top 5 Restaurants in order of their ranks:
#  ['Kalsang Friends Corner', 'TBistro', 'Black Pepper Restaurant', 'Town Table Restaurant', 'Anandam']
# -----------------------------------------
# For Mysore :
#
# Total Restaurants:  20
# Best Restaurant: Vinayaka Mylari
#
# Top 5 Restaurants in order of their ranks:
#  ['Vinayaka Mylari', 'Empire Restaurant', 'Pizza Hut', 'Barbeque Nation', 'The Old House']
# -----------------------------------------
# For Puducherry :
#
# Total Restaurants:  20
# Best Restaurant: Baker Street
#
# Top 5 Restaurants in order of their ranks:
#  ['Baker Street', 'Zuka Choco-la', 'Le Cafe', 'Villa Shanti', 'Tanto Pizzeria']
# -----------------------------------------
# For Surat :
#
# Total Restaurants:  20
# Best Restaurant: Falafel Lovers
#
# Top 5 Restaurants in order of their ranks:
#  ['Falafel Lovers', 'Leonardo Italian Mediterranean Dining', 'Mysore Cafe', 'Black Pepper', 'Coffee Culture - The Ristorante Lounge']
# -----------------------------------------
# For Varanasi :
#
# Total Restaurants:  20
# Best Restaurant: Kashi Chat Bhandar
#
# Top 5 Restaurants in order of their ranks:
#  ['Kashi Chat Bhandar', 'Ming Garden', 'Pizzeria Vaatika Cafe', 'Kerala Cafe', 'VNS Live Studio']
# -----------------------------------------
# For Patna :
#
# Total Restaurants:  20
# Best Restaurant: Pind Balluchi
#
# Top 5 Restaurants in order of their ranks:
#  ['Pind Balluchi', '17 Degrees', 'The Yellow Chilli', "Kapil Dev's Eleven", 'Bansi Vihar']
# -----------------------------------------
# For Dubai :
#
# Total Restaurants:  20
# Best Restaurant: AB's Absolute Barbecues
#
# Top 5 Restaurants in order of their ranks:
#  ["AB's Absolute Barbecues", 'The Cheesecake Factory', 'Tresind - Nassima Royal Hotel', 'Hard Rock Cafe', 'Maharaja Bhog']
# -----------------------------------------
# For Singapore :
#
# Total Restaurants:  19
# Best Restaurant: Fratini La Trattoria
#
# Top 5 Restaurants in order of their ranks:
#  ['Fratini La Trattoria', 'Bitters & Love', 'Jaan', 'Summer Pavilion', 'Cut By Wolfgang Puck']
# -----------------------------------------
# For Sharjah :
#
# Total Restaurants:  20
# Best Restaurant: Rajasthan Al Malaki
#
# Top 5 Restaurants in order of their ranks:
#  ['Rajasthan Al Malaki', 'Najmat Lahore Restaurant', 'Aroos Damascus', 'Nayaab Haandi', 'Gazebo']
# -----------------------------------------
# For Abu Dhabi :
#
# Total Restaurants:  20
# Best Restaurant: The Cheesecake Factory
#
# Top 5 Restaurants in order of their ranks:
#  ['The Cheesecake Factory', 'Via Delhi', 'Pizza Di Rocco', "P.F. Chang's", 'Olive Garden']
# -----------------------------------------
# For Colombo :
#
# Total Restaurants:  20
# Best Restaurant: The Sizzle
#
# Top 5 Restaurants in order of their ranks:
#  ['The Sizzle', 'Ministry of Crab', 'The Commons', "Burger's King", 'The Manhattan Fish Market']
# -----------------------------------------
# For İstanbul :
#
# Total Restaurants:  20
# Best Restaurant: J'adore Chocolatier
#
# Top 5 Restaurants in order of their ranks:
#  ["J'adore Chocolatier", 'Karaköy Güllüoğlu', 'Bayramoğlu Döner', 'Starbucks', 'Ceviz Ağacı']
# -----------------------------------------
# For Ankara :
#
# Total Restaurants:  20
# Best Restaurant: Çukurağa Sofrası
#
# Top 5 Restaurants in order of their ranks:
#  ['Çukurağa Sofrası', 'Meşhur Tavacı Recep Usta', 'Masabaşı Kebapçısı', 'Düveroğlu', 'Düveroğlu']
# -----------------------------------------
# For London :
#
# Total Restaurants:  20
# Best Restaurant: Yauatcha
#
# Top 5 Restaurants in order of their ranks:
#  ['Yauatcha', 'Dishoom', 'Duck & Waffle', 'Bocca Di Lupo', 'Roka']
# -----------------------------------------
# For Doha :
#
# Total Restaurants:  20
# Best Restaurant: Zaffran Dining Experience
#
# Top 5 Restaurants in order of their ranks:
#  ['Zaffran Dining Experience', 'MRA Bakery Sweets & Restaurant', 'Indian Coffee House', 'Aalishan', 'Gokul Gujarati Restaurant']
# -----------------------------------------
# For Makati City :
#
# Total Restaurants:  2
# Best Restaurant: Izakaya Kikufuji
#
# Top 2 Restaurants order of their ranks:
#  ['Izakaya Kikufuji', 'Le Petit Souffle']
# -----------------------------------------
# For Taguig City :
#
# Total Restaurants:  4
# Best Restaurant: The Food Hall by Todd English
#
# Top 4 Restaurants order of their ranks:
#  ['The Food Hall by Todd English', 'NIU by Vikings', 'Wildflour Cafe + Bakery', 'Hobing Korean Dessert Cafe']
# -----------------------------------------
# For Mandaluyong City :
#
# Total Restaurants:  4
# Best Restaurant: Ooma
#
# Top 4 Restaurants order of their ranks:
#  ['Ooma', 'Din Tai Fung', 'Heat - Edsa Shangri-La', 'Sambo Kojin']
# -----------------------------------------
# For Pasay City :
#
# Total Restaurants:  3
# Best Restaurant: Spiral - Sofitel Philippine Plaza Manila
#
# Top 3 Restaurants order of their ranks:
#  ['Spiral - Sofitel Philippine Plaza Manila', 'Vikings', 'Buffet 101']
# -----------------------------------------
# For Pasig City :
#
# Total Restaurants:  3
# Best Restaurant: Silantro Fil-Mex
#
# Top 3 Restaurants order of their ranks:
#  ['Silantro Fil-Mex', 'Locavore', "Mad Mark's Creamery & Good Eats"]
# -----------------------------------------
# For Quezon City :
#
# Total Restaurants:  1
# Best Restaurant: Silantro Fil-Mex
#
# Top 1 Restaurants order of their ranks:
#  ['Silantro Fil-Mex']
# -----------------------------------------
# For Tagaytay City :
#
# Total Restaurants:  1
# Best Restaurant: Balay Dako
#
# Top 1 Restaurants order of their ranks:
#  ['Balay Dako']
# -----------------------------------------
# For San Juan City :
#
# Total Restaurants:  2
# Best Restaurant: Guevarra's
#
# Top 2 Restaurants order of their ranks:
#  ["Guevarra's", 'Sodam Korean Restaurant']
# -----------------------------------------
# For Cape Town :
#
# Total Restaurants:  20
# Best Restaurant: Beluga
#
# Top 5 Restaurants in order of their ranks:
#  ['Beluga', 'Truth Coffee', 'Willoughby & Co.', 'Kloof Street House', 'tashas']
# -----------------------------------------
# For Sandton :
#
# Total Restaurants:  11
# Best Restaurant: Licorish Bistro
#
# Top 5 Restaurants in order of their ranks:
#  ['Licorish Bistro', 'Escondido Tapas', 'Gemelli Cucina Bar', 'Perron', 'Cafe Del Sol Botanico']
# -----------------------------------------
# For Johannesburg :
#
# Total Restaurants:  6
# Best Restaurant: Craft
#
# Top 5 Restaurants in order of their ranks:
#  ['Craft', 'The Wolfpack', 'Hudsons', 'Marble', 'The National']
# -----------------------------------------
# For Inner City :
#
# Total Restaurants:  2
# Best Restaurant: Cube - Tasting Kitchen
#
# Top 2 Restaurants order of their ranks:
#  ['Cube - Tasting Kitchen', 'Urbanologi']
# -----------------------------------------
# For Randburg :
#
# Total Restaurants:  1
# Best Restaurant: The Whippet
#
# Top 1 Restaurants order of their ranks:
#  ['The Whippet']
# -----------------------------------------
# For Brasília :
#
# Total Restaurants:  18
# Best Restaurant: Coco Bambu
#
# Top 5 Restaurants in order of their ranks:
#  ['Coco Bambu', 'Taco Pep', 'Coco Bambu', 'Villa Tevere', 'Maori']
# -----------------------------------------
# For São Paulo :
#
# Total Restaurants:  18
# Best Restaurant: Meats
#
# Top 5 Restaurants in order of their ranks:
#  ['Meats', 'Skye - Hotel Unique', 'Veloso', 'Paris 6 Classique', 'Cantina Famiglia Mancini']
# -----------------------------------------
# For Manchester :
#
# Total Restaurants:  20
# Best Restaurant: San Carlo
#
# Top 5 Restaurants in order of their ranks:
#  ['San Carlo', 'The Grill On The Alley', 'Gaucho', 'Chaophraya', 'Akbars']
# -----------------------------------------
# For Birmingham :
#
# Total Restaurants:  20
# Best Restaurant: Purnell's
#
# Top 5 Restaurants in order of their ranks:
#  ["Purnell's", 'Lasan Restaurant', 'San Carlo', 'Bank', 'Bodega']
# -----------------------------------------
# For Auckland :
#
# Total Restaurants:  20
# Best Restaurant: Milse
#
# Top 5 Restaurants in order of their ranks:
#  ['Milse', 'Federal Delicatessen', 'Giapo', 'Depot Eatery and Oyster Bar', 'Eight - The Langham Hotel']
# -----------------------------------------
# For Wellington City :
#
# Total Restaurants:  20
# Best Restaurant: Fidel's
#
# Top 5 Restaurants in order of their ranks:
#  ["Fidel's", 'The Crab Shack', 'Ekim Burgers', 'The Hangar', 'Floriditas']
# -----------------------------------------
# For Dummy :
#
# Total Restaurants:  1
# Best Restaurant: The Woodlands Eatery
#
# Top 1 Restaurants order of their ranks:
#  ['The Woodlands Eatery']
# -----------------------------------------
# For Rio de Janeiro :
#
# Total Restaurants:  19
# Best Restaurant: Garota de Ipanema
#
# Top 5 Restaurants in order of their ranks:
#  ['Garota de Ipanema', 'Aprazível', 'Braseiro da Gávea', 'Confeitaria Colombo', 'Cervantes']
# -----------------------------------------
# For Jakarta :
#
# Total Restaurants:  16
# Best Restaurant: Talaga Sampireun
#
# Top 5 Restaurants in order of their ranks:
#  ['Talaga Sampireun', 'Talaga Sampireun', 'Toodz House', 'Skye', 'Union Deli']
# -----------------------------------------
# For Bogor :
#
# Total Restaurants:  2
# Best Restaurant: Lemongrass
#
# Top 2 Restaurants order of their ranks:
#  ['Lemongrass', 'Momo Milk']
# -----------------------------------------
# For Tangerang :
#
# Total Restaurants:  2
# Best Restaurant: Talaga Sampireun
#
# Top 2 Restaurants order of their ranks:
#  ['Talaga Sampireun', 'Onokabe']
# -----------------------------------------
# For Pretoria :
#
# Total Restaurants:  20
# Best Restaurant: Kream
#
# Top 5 Restaurants in order of their ranks:
#  ['Kream', 'Capital Craft Beer Academy', 'Harissa Bistro', 'Hogshead', 'Life Grand Cafe']
# -----------------------------------------
# For Edinburgh :
#
# Total Restaurants:  20
# Best Restaurant: La Favorita
#
# Top 5 Restaurants in order of their ranks:
#  ['La Favorita', "Mother India's Cafe", 'The Kitchin', 'The Witchery & The Secret Garden', 'Roseleaf Bar Cafe']
