# %%
## Class4

# %%
import json

# %%
file1 = open("C:\\Users\Aman\\Desktop\\New folder\\file1.json","r")

# %%
a1 =file1.read()
d1 = json.loads(a1)

# %%
d1[0]["restaurants"][0]["restaurant"]["user_rating"]["aggregate_rating"]
# Out:
# '3.3'

# %%
ar =float(d1[0]["restaurants"][0]["restaurant"]["user_rating"]["aggregate_rating"])

# %%
v= float(d1[0]["restaurants"][0]["restaurant"]["user_rating"]["votes"] )

# %%
print(ar*v)
# Out:
# 85.8

# %%
n = d1[0]["restaurants"][0]["restaurant"]["name"]
n
# Out:
# 'Arigato Sushi'

# %%
for j in range (len(d1)):
    # print "j=",j
    if("restaurants" in d1[j]):
        for i in range (0,len(d1[j]["restaurants"])):
            art= float(d1[0]["restaurants"][0]["restaurant"]["user_rating"]["aggregate_rating"])
            vt = float(d1[0]["restaurants"][0]["restaurant"]["user_rating"]["votes"] )
            nt = d1[j]["restaurants"][i]["restaurant"]["name"]
        #print      i=",i
        if (v*ar)<(vt*art):
            n = nt
            v = vt
            ar = art

# %%
print(n,ar ,v)
# Out:
# Arigato Sushi 3.3 26.0

# %%
len(d1[0])
# Out:
# 4

# %%
file2 = open("C:\\Users\Aman\\Desktop\\New folder\\file1.json","r")

# %%
a2 =file2.read()
d2 = json.loads(a2)

# %%
d2[0]["restaurants"][0][""]
# Out:
#   File "<ipython-input-42-75fe66ecb323>", line 1
#     d2[0]["restaurants"][0][]
#                             ^
# SyntaxError: invalid syntax

# %%
file3 = open("C:\\Users\Aman\\Desktop\\New folder\\file2.json","r")

# %%
a3 =file3.read()
d3 = json.loads(a3)

# %%
d3[0]["restaurants"][0]
# Out:
# {'restaurant': {'R': {'res_id': 16668008},
#   'apikey': '10a35f36f5898432823df42bc743c8aa',
#   'average_cost_for_two': 25,
#   'cuisines': 'Asian',
#   'currency': '$',
#   'deeplink': 'zomato://restaurant/16668008',
#   'establishment_types': [],
#   'events_url': 'https://www.zomato.com/yorkton-sk/arigato-sushi-yorkton/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#   'featured_image': '',
#   'has_online_delivery': 0,
#   'has_table_booking': 0,
#   'id': '16668008',
#   'is_delivering_now': 0,
#   'location': {'address': '14 Second Ave North, Yorkton, SK S3N 1G1',
#    'city': 'Yorkton',
#    'city_id': 3600,
#    'country_id': 37,
#    'latitude': '51.2106824000',
#    'locality': 'Yorkton',
#    'locality_verbose': 'Yorkton, Yorkton',
#    'longitude': '-102.4613173000',
#    'zipcode': 'S3N 1G1'},
# ...

# %%
file4 = open("C:\\Users\Aman\\Desktop\\New folder\\file2.json","r")

# %%
a4 =file4.read()
d4 = json.loads(a4)

# %%
d4[0]["restaurants"][0]
# Out:
# {'restaurant': {'R': {'res_id': 16668008},
#   'apikey': '10a35f36f5898432823df42bc743c8aa',
#   'average_cost_for_two': 25,
#   'cuisines': 'Asian',
#   'currency': '$',
#   'deeplink': 'zomato://restaurant/16668008',
#   'establishment_types': [],
#   'events_url': 'https://www.zomato.com/yorkton-sk/arigato-sushi-yorkton/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#   'featured_image': '',
#   'has_online_delivery': 0,
#   'has_table_booking': 0,
#   'id': '16668008',
#   'is_delivering_now': 0,
#   'location': {'address': '14 Second Ave North, Yorkton, SK S3N 1G1',
#    'city': 'Yorkton',
#    'city_id': 3600,
#    'country_id': 37,
#    'latitude': '51.2106824000',
#    'locality': 'Yorkton',
#    'locality_verbose': 'Yorkton, Yorkton',
#    'longitude': '-102.4613173000',
#    'zipcode': 'S3N 1G1'},
# ...

# %%
file5 = open("C:\\Users\Aman\\Desktop\\New folder\\file2.json","r")

# %%
a5 =file5.read()
d5 = json.loads(a5)

# %%
d5[0]["restaurants"][0]
# Out:
# {'restaurant': {'R': {'res_id': 16668008},
#   'apikey': '10a35f36f5898432823df42bc743c8aa',
#   'average_cost_for_two': 25,
#   'cuisines': 'Asian',
#   'currency': '$',
#   'deeplink': 'zomato://restaurant/16668008',
#   'establishment_types': [],
#   'events_url': 'https://www.zomato.com/yorkton-sk/arigato-sushi-yorkton/events#tabtop?utm_source=api_basic_user&utm_medium=api&utm_campaign=v2.1',
#   'featured_image': '',
#   'has_online_delivery': 0,
#   'has_table_booking': 0,
#   'id': '16668008',
#   'is_delivering_now': 0,
#   'location': {'address': '14 Second Ave North, Yorkton, SK S3N 1G1',
#    'city': 'Yorkton',
#    'city_id': 3600,
#    'country_id': 37,
#    'latitude': '51.2106824000',
#    'locality': 'Yorkton',
#    'locality_verbose': 'Yorkton, Yorkton',
#    'longitude': '-102.4613173000',
#    'zipcode': 'S3N 1G1'},
# ...

# %%
file =[d1,d2,d3,d4,d5]

# %%
l =[]
s =[]

# %%
for m in file:
    for i in range(len(m)):
        if("restaurants" in m[i]):
            for j in range(0,len(m[i]["restaurants"])):
                art= float(d1[0]["restaurants"][0]["restaurant"]["user_rating"]["aggregate_rating"])
                vt = float(d1[0]["restaurants"][0]["restaurant"]["user_rating"]["votes"] )
                nt = m[i]["restaurants"][0]["restaurant"]["name"]
        s.append(nt)
        l.append(art*vt)

# %%
import numpy as np

# %%
l = np.array(l)

# %%
l = np.argsort(l)

# %%
for i in range(5):
    print(s[l[i]])
# Out:
# Arigato Sushi
# Arigato Sushi
# Arigato Sushi
# Arigato Sushi
# Arigato Sushi

# %%
l.tolist()
# Out:
# [0,
#  1828,
#  1829,
#  1830,
#  1831,
#  1832,
#  1833,
#  1834,
#  1835,
#  1836,
#  1837,
#  1838,
#  1839,
#  1840,
#  1841,
#  1842,
#  1843,
#  1844,
#  1827,
#  1845,
#  1826,
#  1824,
#  1807,
#  1808,
#  1809,
#  1810,
#  1811,
#  1812,
#  1813,
#  1814,
#  1815,
#  1816,
#  1817,
#  1818,
#  1819,
#  1820,
#  1821,
#  1822,
#  1823,
#  1825,
#  1846,
#  1847,
#  1848,
#  1871,
#  1872,
#  1873,
#  1874,
#  1875,
#  1876,
#  1877,
#  1878,
#  1879,
#  1880,
#  1881,
#  1882,
#  1883,
#  1884,
#  1885,
#  1886,
#  1887,
#  1870,
#  1869,
#  1868,
#  1867,
#  1849,
#  1850,
#  1851,
#  1852,
#  1853,
#  1854,
#  1855,
#  1856,
#  1806,
#  1857,
#  1859,
#  1860,
#  1861,
#  1862,
#  1863,
#  1864,
#  1865,
#  1866,
#  1858,
#  1805,
#  1804,
#  1803,
#  1743,
#  1744,
#  1745,
#  1746,
#  1747,
#  1748,
#  1749,
#  1750,
#  1751,
#  1752,
#  1753,
#  1754,
#  1755,
#  1756,
#  1757,
#  1758,
#  1759,
#  1742,
#  1741,
#  1740,
#  1739,
#  1721,
#  1722,
#  1723,
#  1724,
# ...
