# %%
import pandas as pd

# %%
td = pd.read_csv("Titanic.csv")

# %%
td
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
td["Name"]
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
# 5                                       Moran, Mr. James
# 6                                McCarthy, Mr. Timothy J
# 7                         Palsson, Master. Gosta Leonard
# 8      Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                    Nasser, Mrs. Nicholas (Adele Achem)
# 10                       Sandstrom, Miss. Marguerite Rut
# 11                              Bonnell, Miss. Elizabeth
# 12                        Saundercock, Mr. William Henry
# 13                           Andersson, Mr. Anders Johan
# 14                  Vestrom, Miss. Hulda Amanda Adolfina
# 15                      Hewlett, Mrs. (Mary D Kingcome)
# ...

# %%
 m = td["Sex"] == "Male"

# %%
m
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862    False
# 863    False
# 864    False
# 865    False
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# 871    False
# 872    False
# 873    False
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879    False
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885    False
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
len(m)
# Out:
# 891

# %%
male = 0
women = 0
for i in range(len(td)):
    if td["Sex"][i] == "male":
        male+= 1
    else:
        women+=1

# %%
male
# Out:
# 577

# %%
women
# Out:
# 314

# %%
td["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
import matplotlib.pyplot as plt
sizes = [male,women]
labels = ['male','women']
plt.pie(sizes,labels = labels)
plt.show()

# %%
td["Survived"].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
male = 0
women = 0
for i in range(len(td)):
    if td["Survived"][i] == 0:
        if td["Sex"][i] =="male":
           
             male+= 1
        else:
             women+=1

# %%
male
# Out:
# 468

# %%
women
# Out:
# 81

# %%
sizes = [male,women]
labels = ['male','women']
plt.pie(sizes,labels = labels)
plt.show()

# %%
fare_m=[]
age_m =[]
fare_f=[]
age_f=[]

for i in range(len(td)):
    if( td["Age"][i]>0) :
        if td["Sex"][i] == "male":
            fare_m.append(td["Fare"][i])
            age_m.append(td["Age"][i])
        else:
            fare_f.append(td["Fare"][i])
            age_f.append(td["Age"][i])

# %%
x = plt.scatter(fare_m,age_m,color="blue")
y = plt.scatter(fare_f,age_f,color="orange")
plt.show(x,y)

# %%
age =[]
fare=[]
for i in range(len(td)):
    if(td["Survived"][i] ==0):
        if(td["Age"][i]>0):
            age.append(td["Age"][i])
            fare.append(td["Fare"][i])

# %%
age
# Out:
# [22.0,
#  35.0,
#  54.0,
#  2.0,
#  20.0,
#  39.0,
#  14.0,
#  2.0,
#  31.0,
#  35.0,
#  8.0,
#  19.0,
#  40.0,
#  66.0,
#  28.0,
#  42.0,
#  21.0,
#  18.0,
#  40.0,
#  27.0,
#  18.0,
#  7.0,
#  21.0,
#  65.0,
#  28.5,
#  11.0,
#  22.0,
#  45.0,
#  4.0,
#  19.0,
#  26.0,
#  32.0,
#  16.0,
#  21.0,
#  26.0,
#  25.0,
#  22.0,
#  28.0,
#  16.0,
#  24.0,
#  29.0,
#  20.0,
#  46.0,
#  26.0,
#  59.0,
#  71.0,
#  34.0,
#  28.0,
#  21.0,
#  33.0,
#  37.0,
#  28.0,
#  38.0,
#  47.0,
#  14.5,
#  22.0,
#  20.0,
#  17.0,
#  21.0,
#  70.5,
#  29.0,
#  24.0,
#  2.0,
#  21.0,
#  32.5,
#  54.0,
#  45.0,
#  33.0,
#  20.0,
#  47.0,
#  25.0,
#  23.0,
#  37.0,
#  16.0,
#  24.0,
#  19.0,
#  18.0,
#  19.0,
#  9.0,
#  36.5,
#  42.0,
#  51.0,
#  55.5,
#  40.5,
#  51.0,
#  30.0,
#  44.0,
#  26.0,
#  17.0,
#  1.0,
#  45.0,
#  28.0,
#  61.0,
#  4.0,
#  21.0,
#  56.0,
#  18.0,
#  50.0,
#  30.0,
#  36.0,
#  9.0,
#  40.0,
#  36.0,
#  19.0,
#  42.0,
#  24.0,
#  28.0,
#  34.0,
#  45.5,
#  2.0,
#  32.0,
#  24.0,
# ...

# %%
plt.hist(age)
plt.show()

# %%
td["Age"].max()
# Out:
# 80.0

# %%
plt.hist(fare)
plt.show()

# %%
td["Pclass"].min()
# Out:
# 1

# %%
pclass =[]
for i in range(len(td)):
    if(td["Survived"][i] ==0):
        pclass.append(td["Pclass"][i])

# %%
plt.hist(pclass)
plt.show()

# %%
list =[]
for i in range(len(td)):
    if td["Survived"][i] == 0:
        if td["Sex"][i] =="male":
           
             list.append(0)
        else:
             list.append(1)

# %%
plt.hist(list)
plt.show()
