# %%
import pandas as pd
import sklearn.linear_model
import numpy as np
import matplotlib.pyplot as plt

# %%
import sklearn
import sklearn.datasets

# %%
og = pd.read_csv("Oil_gas.csv")

# %%
og
# Out:
#           cty_name  iso3numeric   id  year       eiacty  oil_prod32_14  \
# 0      Afghanistan            4  AFG  1932  Afghanistan            NaN
# 1      Afghanistan            4  AFG  1933  Afghanistan            NaN
# 2      Afghanistan            4  AFG  1934  Afghanistan            NaN
# 3      Afghanistan            4  AFG  1935  Afghanistan            NaN
# 4      Afghanistan            4  AFG  1936  Afghanistan            NaN
# 5      Afghanistan            4  AFG  1937  Afghanistan            NaN
# 6      Afghanistan            4  AFG  1938  Afghanistan            NaN
# 7      Afghanistan            4  AFG  1939  Afghanistan            NaN
# 8      Afghanistan            4  AFG  1940  Afghanistan            NaN
# 9      Afghanistan            4  AFG  1941  Afghanistan            NaN
# 10     Afghanistan            4  AFG  1942  Afghanistan            NaN
# 11     Afghanistan            4  AFG  1943  Afghanistan            NaN
# ...

# %%
gp=[]
gpn=[]
for i in range(len(og)):
    if(og["gas_prod55_14"][i]!=str("nan")):
            gp.append(og["gas_prod55_14"][i])
            gpn.append(og["gas_price_nom"][i])
        
 #  list indices must be integers or slices, not str

# %%
x = plt.scatter(gp,gpn,color="orange")
plt.show(x)

# %%
len(og)
# Out:
# 15521

# %%
yr=[]
pr=[]
for i in range(len(og)):
    if(og["gas_price_nom"][i]!=0):
            yr.append(og["year"][i])
            pr.append(og["gas_price_nom"][i])

# %%
y = plt.scatter(yr,pr ,color="orange")
plt.show(y)
