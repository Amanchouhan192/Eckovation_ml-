# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
import sklearn.linear_model
import sklearn.datasets

# %%
boston = sklearn.datasets.load_boston()

# %%
#feature names
fn = boston.feature_names

# %%
fn
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'],
#       dtype='<U7')

# %%
#for real data

boston.data
# Out:
# array([[  6.32000000e-03,   1.80000000e+01,   2.31000000e+00, ...,
#           1.53000000e+01,   3.96900000e+02,   4.98000000e+00],
#        [  2.73100000e-02,   0.00000000e+00,   7.07000000e+00, ...,
#           1.78000000e+01,   3.96900000e+02,   9.14000000e+00],
#        [  2.72900000e-02,   0.00000000e+00,   7.07000000e+00, ...,
#           1.78000000e+01,   3.92830000e+02,   4.03000000e+00],
#        ...,
#        [  6.07600000e-02,   0.00000000e+00,   1.19300000e+01, ...,
#           2.10000000e+01,   3.96900000e+02,   5.64000000e+00],
#        [  1.09590000e-01,   0.00000000e+00,   1.19300000e+01, ...,
#           2.10000000e+01,   3.93450000e+02,   6.48000000e+00],
#        [  4.74100000e-02,   0.00000000e+00,   1.19300000e+01, ...,
#           2.10000000e+01,   3.96900000e+02,   7.88000000e+00]])

# %%
print(boston.data.shape)
# Out:
# (506, 13)

# %%
 bd = pd.DataFrame(boston.data,columns =fn)

# %%
bd
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS   RAD    TAX  \
# 0     0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900   1.0  296.0
# 1     0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671   2.0  242.0
# 2     0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671   2.0  242.0
# 3     0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622   3.0  222.0
# 4     0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622   3.0  222.0
# 5     0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622   3.0  222.0
# 6     0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605   5.0  311.0
# 7     0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505   5.0  311.0
# 8     0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821   5.0  311.0
# 9     0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921   5.0  311.0
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467   5.0  311.0
# ...

# %%
len(fn)
# Out:
# 13

# %%
bd.hist()
plt.show()

# %%
import matplotlib.pyplot as plt
sizes = [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD,TAX, PTRATIO, B, LSTAT]
#labels = [CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
plt.pie(sizes,labels = labels)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-158-b140bce6581f> in <module>()
#       1 import matplotlib.pyplot as plt
# ----> 2 sizes = [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD,TAX, PTRATIO, B, LSTAT]
#       3 #labels = [CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']
#       4 plt.pie(sizes,labels = labels)
#       5 plt.show()
#
# NameError: name 'CRIM' is not defined

# %%
bd["CRIM"]

# %%
crim=[]
zn=[]

for i in range(len(bd)):
    crim.append(bd["CRIM"][i])
    zn.append(bd["ZN"][i])

# %%
crim
# Out:
# 0       0.00632
# 1       0.02731
# 2       0.02729
# 3       0.03237
# 4       0.06905
# 5       0.02985
# 6       0.08829
# 7       0.14455
# 8       0.21124
# 9       0.17004
# 10      0.22489
# 11      0.11747
# 12      0.09378
# 13      0.62976
# 14      0.63796
# 15      0.62739
# 16      1.05393
# 17      0.78420
# 18      0.80271
# 19      0.72580
# 20      1.25179
# 21      0.85204
# 22      1.23247
# 23      0.98843
# 24      0.75026
# 25      0.84054
# 26      0.67191
# 27      0.95577
# 28      0.77299
# 29      1.00245
#          ...
# 476     4.87141
# 477    15.02340
# 478    10.23300
# 479    14.33370
# 480     5.82401
# 481     5.70818
# 482     5.73116
# 483     2.81838
# 484     2.37857
# 485     3.67367
# 486     5.69175
# 487     4.83567
# 488     0.15086
# 489     0.18337
# 490     0.20746
# 491     0.10574
# 492     0.11132
# 493     0.17331
# 494     0.27957
# 495     0.17899
# 496     0.28960
# 497     0.26838
# 498     0.23912
# 499     0.17783
# ...

# %%
dic={}
for i in boston.feature_names:
    dic[i] =[]

# %%
dic
# Out:
# {'AGE': [],
#  'B': [],
#  'CHAS': [],
#  'CRIM': [],
#  'DIS': [],
#  'INDUS': [],
#  'LSTAT': [],
#  'NOX': [],
#  'PTRATIO': [],
#  'RAD': [],
#  'RM': [],
#  'TAX': [],
#  'ZN': []}

# %%
dic2 ={}
for i in dic:
    for j in dic[i]:
        dic2[i] +=j
# Out:
#   File "<ipython-input-169-8ea5ffa4a981>", line 2
#     for i in range(len(dic):
#                            ^
# SyntaxError: invalid syntax

# %%
sizes =list(dic2.values())
labels =list(dic2.keys())
plt.pie(sizes)
#plt.legend(labels,loc=0,frameon=0)
plt.show()
